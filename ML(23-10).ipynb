# %% [markdown]
# ## Excersice
# - Predict Canada's per capita income in year 2020. Using file, build a regression model and predict the per capita income of canadian citizens in year 2020.

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Canada_per_capita_income.csv")

# %%
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
df.rename(columns={"per capita income (US$)":"per_capita_income"},inplace=True)

# %%
df
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
plt.scatter(df.year,df.per_capita_income,color="purple",marker="*")

# %%
df1=df.drop("per_capita_income",axis="columns")

# %%
df1
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
income=df.per_capita_income

# %%
income
# Out:
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# 22    16412.083090
# 23    15875.586730
# 24    15755.820270
# 25    16369.317250
# 26    16699.826680
# 27    17310.757750
# 28    16622.671870
# 29    17581.024140
# 30    18987.382410
# 31    18601.397240
# 32    19232.175560
# 33    22739.426280
# 34    25719.147150
# 35    29198.055690
# 36    32738.262900
# 37    36144.481220
# 38    37446.486090
# 39    32755.176820
# 40    38420.522890
# 41    42334.711210
# 42    42665.255970
# 43    42676.468370
# 44    41039.893600
# 45    35175.188980
# 46    34229.193630
# ...

# %%
reg=linear_model.LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.fit(df1,income)
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])

# %%
reg.predict([[2013]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35489.43856786])

# %%
import seaborn as sns
sns.regplot(x=df.year,y=df.per_capita_income,data=df,ci=None)
# Out:
# <Axes: xlabel='year', ylabel='per_capita_income'>

# %%
df2=pd.read_csv("Home_prices.csv")

# %%
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df2.bedrooms.median()
# Out:
# np.float64(4.0)

# %%
df2.bedrooms=df2.bedrooms.fillna(df2.bedrooms.median())

# %%
df2
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df3['x_combined'] = df3['area'] + df3['bedrooms'] + df2['age']
ax=sns.regplot(x=df3.x_combined,y=df2.price,data=df2,ci=None)

# %%
reg1=linear_model.LinearRegression()

# %%
reg1
# Out:
# LinearRegression()

# %%
df3=df2.drop('price',axis='columns')

# %%
df3
# Out:
#    area  bedrooms  age
# 0  2600       3.0   20
# 1  3000       4.0   15
# 2  3200       4.0   18
# 3  3600       3.0   30
# 4  4000       5.0    8
# 5  4100       6.0    8

# %%
price=df2.price

# %%
price
# Out:
# 0    550000
# 1    565000
# 2    610000
# 3    595000
# 4    760000
# 5    810000
# Name: price, dtype: int64

# %%
reg1.fit(df3,price)
# Out:
# LinearRegression()

# %%
reg1.predict([[3000,3,12]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([588896.35302203])

# %%
import plotly.express as px

# %%
fig=px.scatter(df,x=df3.age,y=price)
fig.show()
